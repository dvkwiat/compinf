# %%
#--------------------Main Code--------------------#

# %run "Theory Section.ipynb"
# %run "Data Background.ipynb"
# %run "Results Section.ipynb"
# %run "MSE Calculation.ipynb"
# %run "QRE.ipynb"
# %run "Trembling Hand.ipynb"
# %run "Price Grid.ipynb"
# %run "zTree Images.ipynb"
# %run "Results with Both Orders.ipynb"
# Out:
# Running Theory Section
# Data written to eqa.npz
# Data written to inf.npz
# timing.tex created
# belief_space.tex created
# seller_strat_space.tex created
# Data written to ../output/Theory Section/avgprice.data
# average_price.tex created
# seller_strat_space_2.tex created
# Data written to ../output/Theory Section/informativeness.data
# informativeness.tex created
# Created basin_high.tex
#
#
# Running Data Background
# Combining data...
# Separating treatments...
# Saving data by treatment...
# Aggregating by subject, round, and session...
# Saving aggregated data...
# Done.
#
# Running Results Section
# Testing for order effects...
# Created wilcoxon_test_vars.tex
# Created sellerstrat_byseller_first.tex
# Created buyerstrat_bybuyer_first.tex
# Created sellerstrat_bysession_CIs_first.tex
# Data written to ../output/Results Section/sellerstrat_bysession_first.data
# Created permutation_tests_first.tex
#
#
# Running MSE Calculation
# Created mse_table.tex
# Created mse_vars.tex
#
# ...
